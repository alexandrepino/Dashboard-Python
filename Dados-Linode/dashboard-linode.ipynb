# %% [markdown]
# # Integração do Python com a API da Linode para extrair dados de consumo de memória do mês 04-2022 e gerando um grafico no servidor

# %%
#Importando as biblioteca utilizadas no projeto

from dash import Dash, html, dcc
import plotly.express as px
import pandas as pd
import requests
import json
import calendar
from datetime import datetime
import plotly.graph_objects as go

app = Dash(__name__)

d           = datetime.now()
month_range = calendar.monthrange(d.year, d.month)

opcoes = [f'{d.month}-{d.year}',f'{d.month-1}-{d.year}']
opcoes.append('todas as datas')



AUTHORIZATION   = '647f0f245c0fcd287d4531b6864794cb18cdee31822ad6c5a58dc76ec078dff4'
ID              = '29993461'
URL_TOTAL_BYTES = f'https://api.linode.com/v4/linode/instances/{ID}/transfer/{d.year}/{d.month}'

headers = {'Authorization': 'Bearer '+AUTHORIZATION}

r = requests.get(URL_TOTAL_BYTES, headers=headers)
r_json = r.json()

r_df = pd.DataFrame.from_dict(r_json,orient='index')
r_df = r_df.reset_index()
r_df = r_df.rename(columns={0:'bytes'})
r_df.drop(r_df.loc[r_df['index'] == 'bytes_in'].index, inplace=True)
r_df.drop(r_df.loc[r_df['index'] == 'bytes_out'].index, inplace=True)
r_df.loc[r_df['index']  == 'bytes_total', 'index'] = 'Linode'
r_df = r_df.rename(columns={'index':'provedor'})
r_df['terabytes'] = r_df['bytes'] / 1024 ** 4
r_df['terabytes'] = r_df['terabytes'].round(2)
tera = r_df['terabytes'].values[0]




fig = go.Figure(go.Indicator(
    mode = "gauge+number",
    value = tera,
    
    title = {'text': "Dados consumidos em Terabytes"},
    domain = {'x': [0, 1], 'y': [0, 1]},
    gauge = {'axis': {'range': [None, 16]},
             'steps' : [
                 {'range': [0, 16], 'color': "lightgray"},
                 {'range':[6, 10], 'color': "yellow"},
                 {'range': [10, 16], 'color': "red"}],
             'threshold' : {'line': {'color': "red", 'width': 4}, 'thickness': 0.75, 'value': 490}}))


app.layout = html.Div(children=[
    html.H1(children='Linode'),

    html.Div(children=f'''
        Consumo total do mes {d.month}-{d.year}:
    '''),
    dcc.Dropdown(opcoes,value = 'todas as data',id='Datas'),
    dcc.Graph(
        id='example-graph',
        figure=fig
    )
])

if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [07/Apr/2022 11:29:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2022 11:29:38] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2022 11:29:38] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2022 11:29:38] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [07/Apr/2022 11:29:38] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [07/Apr/2022 11:29:38] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [07/Apr/2022 11:46:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2022 11:46:44] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2022 11:46:44] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2022 11:46:44] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2022 11:46:44] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [07/Apr/2022 11:46:44] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [07/Apr/2022 11:46:45] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -

# %%
app = Dash(__name__)

d           = datetime.now()
month_range = calendar.monthrange(d.year, d.month)

opcoes = [f'{d.month}-{d.year}',f'{d.month-1}-{d.year}']
opcoes.append('todas as datas')



AUTHORIZATION   = '647f0f245c0fcd287d4531b6864794cb18cdee31822ad6c5a58dc76ec078dff4'
ID              = '29993461'
URL_TOTAL_BYTES = f'https://api.linode.com/v4/linode/instances/{ID}/transfer/{d.year}/{d.month-1}'

headers = {'Authorization': 'Bearer '+AUTHORIZATION}

r = requests.get(URL_TOTAL_BYTES, headers=headers)
r_json = r.json()

r_df = pd.DataFrame.from_dict(r_json,orient='index')
r_df = r_df.reset_index()
r_df = r_df.rename(columns={0:'bytes'})
r_df.drop(r_df.loc[r_df['index'] == 'bytes_in'].index, inplace=True)
r_df.drop(r_df.loc[r_df['index'] == 'bytes_out'].index, inplace=True)
r_df.loc[r_df['index']  == 'bytes_total', 'index'] = 'Linode'
r_df = r_df.rename(columns={'index':'provedor'})
r_df['terabytes'] = r_df['bytes'] / 1024 ** 4
r_df['terabytes'] = r_df['terabytes'].round(2)
tera = r_df['terabytes'].values[0]




fig = go.Figure(go.Indicator(
    mode = "gauge+number",
    value = tera,
    
    title = {'text': "Dados consumidos em Terabytes"},
    domain = {'x': [0, 1], 'y': [0, 1]},
    gauge = {'axis': {'range': [None, 16]},
             'steps' : [
                 {'range': [0, 16], 'color': "lightgray"},
                 {'range':[6, 10], 'color': "yellow"},
                 {'range': [10, 16], 'color': "red"}],
             'threshold' : {'line': {'color': "red", 'width': 4}, 'thickness': 0.75, 'value': 490}}))


app.layout = html.Div(children=[
    html.H1(children='Linode'),

    html.Div(children=f'''
        Consumo total do mês {d.month-1}-{d.year}:
    '''),
    dcc.Dropdown(opcoes,value = 'todas as data',id='Datas'),
    dcc.Graph(
        id='example-graph',
        figure=fig
    )
])

if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [07/Apr/2022 11:46:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2022 11:46:57] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2022 11:46:57] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2022 11:46:57] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [07/Apr/2022 11:46:57] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [07/Apr/2022 11:46:57] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [07/Apr/2022 11:49:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2022 11:49:05] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2022 11:49:05] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2022 11:49:05] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [07/Apr/2022 11:49:05] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [07/Apr/2022 11:49:05] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
